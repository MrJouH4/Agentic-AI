# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")

response = llm.invoke("What is Jou Dev channel")
print(response.text)
# Out:
# Based on available information, **Jou Dev** is a YouTube channel and content creation brand focused on **software development, programming, and technology education.**
#
# While there are several small creators with similar names, the most prominent "Jou Dev" presence is known for providing educational content specifically aimed at helping aspiring developers learn how to code.
#
# Here are the key characteristics of the channel:
#
# 1.  **Educational Focus:** The channel typically focuses on teaching programming languages (such as Python, JavaScript, or C#) and web development frameworks.
# 2.  **Target Audience:** It is primarily aimed at beginners and intermediate learners who want to enter the field of software engineering.
# 3.  **Language:** Much of the content is geared toward the **Arabic-speaking community**, often explaining complex technical concepts in Arabic to make them more accessible to students in that region.
# ...
